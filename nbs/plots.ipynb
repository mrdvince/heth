# %%
import os
import rasterio as rio
import satsearch
from json import load
from rasterio.features import bounds
from rasterio.plot import show
import matplotlib.pyplot as plt
from pyproj import Transformer

# %matplotlib inline

# %%
file_path = "../data/map.geojson"
file_content = load(open(file_path))
geometry = file_content["features"][0]["geometry"]

timeRange = '2022-01-01/2022-08-01'

# %%
SentinelSearch = satsearch.Search.search( 
    url = "https://earth-search.aws.element84.com/v0",
    intersects = geometry,
    datetime = timeRange,
    collections = ['sentinel-s2-l2a-cogs'] )
search_items = SentinelSearch.items()

# %%
items = items[:10]

# %%
for item in items:
    print(item.assets["overview"]["href"])
# Out:
# https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/36/M/ZE/2022/8/S2A_36MZE_20220801_0_L2A/L2A_PVI.tif
# https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/37/M/BV/2022/8/S2A_37MBV_20220801_0_L2A/L2A_PVI.tif
# https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/37/M/CV/2022/8/S2A_37MCV_20220801_0_L2A/L2A_PVI.tif
# https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/37/M/DV/2022/8/S2A_37MDV_20220801_0_L2A/L2A_PVI.tif
# https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/36/N/ZF/2022/8/S2A_36NZF_20220801_0_L2A/L2A_PVI.tif
# https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/37/N/BA/2022/8/S2A_37NBA_20220801_0_L2A/L2A_PVI.tif
# https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/37/N/CA/2022/8/S2A_37NCA_20220801_0_L2A/L2A_PVI.tif
# https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/37/N/DA/2022/8/S2A_37NDA_20220801_0_L2A/L2A_PVI.tif
# ...

# %%
for idx, item in enumerate(items):
    tiff = rio.open(item.assets["overview"]["href"])
    show(tiff.read(), transform=tiff.transform)

# %%
tiff = rio.open(item[0].assets["overview"]["href"])
show(tiff.read(), transform=tiff.transform)
